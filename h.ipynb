# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# Load data from JSON file
with open('data.json', 'r') as f:
    data = json.load(f)

# Convert data to a pandas DataFrame
df = pd.DataFrame(data)

# Extract the required columns
tc = [1, 2, 3]  # Assuming TC values for now
prims_speedup = df["Prim's Speedup"]
dcran_speedup = df["DCRAN Speedup"]

# Create the plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=tc, y=prims_speedup, marker='o', color='r', label='Prim\'s Speedup')
sns.scatterplot(x=tc, y=dcran_speedup, marker='s', color='g', label='DCRAN Speedup')

# Set labels and title
plt.xlabel('Time Complexity')
plt.ylabel('Speedup')
plt.title('Speedup vs Time Complexity')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 15
#      13 # Extract the required columns
#      14 tc = [1, 2, 3]  # Assuming TC values for now
# ---> 15 prims_speedup = df["Prim's Speedup"]
#      16 dcran_speedup = df["DCRAN Speedup"]
#      18 # Create the plot
#
# File ~/miniconda3/envs/gpy12/lib/python3.12/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/miniconda3/envs/gpy12/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
# ...

# %%
import json
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from data.json
with open('data.json') as file:
    data = json.load(file)

# Extract the relevant data for plotting
dcran_speedup = [row[-1] for row in data]
prims_speedup = [row[-2] for row in data]

# Create a DataFrame for plotting
df = pd.DataFrame({'DCRAN Speedup': dcran_speedup, 'Prim\'s Speedup': prims_speedup})

# Set the Seaborn style
sns.set(style='whitegrid')

# Create the plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='DCRAN Speedup', y='Prim\'s Speedup', color='blue', alpha=0.7)

# Add labels and title
plt.xlabel('DCRAN Speedup', fontsize=12)
plt.ylabel('Prim\'s Speedup', fontsize=12)
plt.title('DCRAN Speedup vs Prim\'s Speedup', fontsize=14)

# Add a diagonal line for reference
x = np.linspace(0, max(dcran_speedup), 100)
plt.plot(x, x, color='red', linestyle='--', label='Equal Speedup')

# Add a legend
plt.legend(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 29
#      26 plt.title('DCRAN Speedup vs Prim\'s Speedup', fontsize=14)
#      28 # Add a diagonal line for reference
# ---> 29 x = np.linspace(0, max(dcran_speedup), 100)
#      30 plt.plot(x, x, color='red', linestyle='--', label='Equal Speedup')
#      32 # Add a legend
#
# NameError: name 'np' is not defined

# %%
import json
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load the data from data.json
with open('data.json') as file:
    data = json.load(file)

# Extract the relevant data for plotting
dcran_speedup = [row[-1] for row in data]
prims_speedup = [row[-2] for row in data]

# Create a DataFrame for plotting
df = pd.DataFrame({'DCRAN Speedup': dcran_speedup, 'Prim\'s Speedup': prims_speedup})

# Set the Seaborn style
sns.set(style='whitegrid')

# Create the plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='DCRAN Speedup', y='Prim\'s Speedup', color='blue', alpha=0.7)

# Add labels and title
plt.xlabel('DCRAN Speedup', fontsize=12)
plt.ylabel('Prim\'s Speedup', fontsize=12)
plt.title('DCRAN Speedup vs Prim\'s Speedup', fontsize=14)

# Add a diagonal line for reference
x = np.linspace(0, max(dcran_speedup), 100)
plt.plot(x, x, color='red', linestyle='--', label='Equal Speedup')

# Add a legend
plt.legend(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import json
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from data.json
with open('data.json') as file:
    data = json.load(file)

# Extract the relevant data for plotting
points = [row[1] for row in data]
dcran_speedup = [row[-1] for row in data]
prims_speedup = [row[-2] for row in data]

# Create a DataFrame for plotting
df = pd.DataFrame({'Points': points, 'DCRAN Speedup': dcran_speedup, 'Prim\'s Speedup': prims_speedup})

# Set the Seaborn style
sns.set(style='whitegrid')

# Create the plot
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x='Points', y='DCRAN Speedup', color='blue', label='DCRAN Speedup', marker='o')
sns.lineplot(data=df, x='Points', y='Prim\'s Speedup', color='red', label='Prim\'s Speedup', marker='o')

# Set the x-axis to logarithmic scale
plt.xscale('log')

# Add labels and title
plt.xlabel('Number of Points', fontsize=12)
plt.ylabel('Speedup', fontsize=12)
plt.title('Speedup vs Number of Points', fontsize=14)

# Add a legend
plt.legend(fontsize=10)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import json
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from data.json
with open('data.json') as file:
    data = json.load(file)

# Extract the relevant data for plotting
points = [row[1] for row in data]
dcran_speedup = [row[-1] for row in data]
prims_speedup = [row[-2] for row in data]

# Create a DataFrame for plotting
df = pd.DataFrame({'Points': points, 'DCRAN Speedup': dcran_speedup, 'Prim\'s Speedup': prims_speedup})

# Set the Seaborn style
sns.set(style='whitegrid', font_scale=0.8)

# Create the plot
fig, ax = plt.subplots(figsize=(3.5, 2.5))
sns.lineplot(data=df, x='Points', y='DCRAN Speedup', color='blue', label='DCRAN Speedup', marker='o', ax=ax)
sns.lineplot(data=df, x='Points', y='Prim\'s Speedup', color='red', label='Prim\'s Speedup', marker='o', ax=ax)

# Set the x-axis to logarithmic scale
ax.set_xscale('log')

# Add labels and title
ax.set_xlabel('Number of Points', fontsize=8)
ax.set_ylabel('Speedup', fontsize=8)
ax.set_title('Speedup vs Number of Points', fontsize=10)

# Adjust tick label font size
ax.tick_params(axis='both', which='major', labelsize=6)

# Add a legend
ax.legend(fontsize=6)

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig('speedup_plot.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import json
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from data.json
with open('data.json') as file:
    data = json.load(file)

# Extract the relevant data for plotting
points = [row[1] for row in data]
prims_time = [row[-3] for row in data]
dcran_time = [row[-5] for row in data]
fmst_time = [row[-4] for row in data]

# Create a DataFrame for plotting
df = pd.DataFrame({'Points': points, 'Prim\'s Time': prims_time, 'DCRAN Time': dcran_time, 'FMST Time': fmst_time})

# Set the Seaborn style
sns.set(style='whitegrid', font_scale=0.8)

# Create the plot
fig, ax = plt.subplots(figsize=(3.5, 2.5))
sns.lineplot(data=df, x='Points', y='Prim\'s Time', color='red', label='Prim\'s Time', marker='o', ax=ax)
sns.lineplot(data=df, x='Points', y='DCRAN Time', color='blue', label='DCRAN Time', marker='o', ax=ax)
sns.lineplot(data=df, x='Points', y='FMST Time', color='green', label='FMST Time', marker='o', ax=ax)

# Set the x-axis to logarithmic scale
ax.set_xscale('log')

# Add labels and title
ax.set_xlabel('Number of Points', fontsize=8)
ax.set_ylabel('Time (s)', fontsize=8)
ax.set_title('Execution Time vs Number of Points', fontsize=10)

# Adjust tick label font size
ax.tick_params(axis='both', which='major', labelsize=6)

# Add a legend
ax.legend(fontsize=6)

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig('execution_time_plot.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import json
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from data.json
with open('data.json') as file:
    data = json.load(file)

# Extract the relevant data for plotting
points = [row[1] for row in data]
prims_weight = [row[5] for row in data]
dcran_weight = [row[3] for row in data]
fmst_weight = [row[4] for row in data]

# Calculate the weight error between DCRAN and Prim's
dcran_error = [abs(prims - dcran) / prims * 100 for prims, dcran in zip(prims_weight, dcran_weight)]

# Calculate the weight error between FMST and Prim's
fmst_error = [abs(prims - fmst) / prims * 100 for prims, fmst in zip(prims_weight, fmst_weight)]

# Create a DataFrame for plotting
df = pd.DataFrame({'Points': points, 'DCRAN Error (%)': dcran_error, 'FMST Error (%)': fmst_error})

# Set the Seaborn style
sns.set(style='whitegrid', font_scale=0.8)

# Create the plot
fig, ax = plt.subplots(figsize=(3.5, 2.5))
sns.lineplot(data=df, x='Points', y='DCRAN Error (%)', color='blue', label='DCRAN Error', marker='o', ax=ax)
sns.lineplot(data=df, x='Points', y='FMST Error (%)', color='green', label='FMST Error', marker='o', ax=ax)

# Set the x-axis to logarithmic scale
ax.set_xscale('log')

# Add labels and title
ax.set_xlabel('Number of Points', fontsize=8)
ax.set_ylabel('Weight Error (%)', fontsize=8)
ax.set_title('Weight Error vs Prim\'s', fontsize=10)

# Adjust tick label font size
ax.tick_params(axis='both', which='major', labelsize=6)

# Add a legend
ax.legend(fontsize=6)

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig('weight_error_prims_plot.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import time
from sklearn.cluster import KMeans
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
import numpy as np

def euclidean_distance(p1, p2):
    return sum((a - b) ** 2 for a, b in zip(p1, p2)) ** 0.5

def prims_mst(points):
    n = len(points)
    pairwise_distances = squareform(pdist(points))
    
    mst_edges = []
    total_weight = 0
    visited = [False] * n
    visited[0] = True
    
    for _ in range(n - 1):
        min_weight = float("inf")
        min_u, min_v = None, None
        
        for u in range(n):
            if visited[u]:
                for v in range(n):
                    if not visited[v] and pairwise_distances[u][v] < min_weight:
                        min_weight = pairwise_distances[u][v]
                        min_u, min_v = u, v
        
        mst_edges.append((points[min_u], points[min_v]))
        total_weight += min_weight
        visited[min_v] = True
    
    return mst_edges, total_weight

def fast_mst(points):
    n = len(points)
    k = int(n**0.5)
    
    # Divide-and-conquer stage
    kmeans = KMeans(n_clusters=k).fit(points)
    labels = kmeans.labels_
    centers = kmeans.cluster_centers_.tolist()
    
    mst_edges = []
    total_weight = 0
    
    for i in range(k):
        cluster_points = [points[j] for j in range(n) if labels[j] == i]
        cluster_mst_edges, cluster_weight = prims_mst(cluster_points)
        mst_edges.extend(cluster_mst_edges)
        total_weight += cluster_weight
        
        # Visualize the MST for each cluster
        plt.figure()
        for x, y in cluster_points:
            plt.scatter(x, y, color='blue')
        for (x1, y1), (x2, y2) in cluster_mst_edges:
            plt.plot([x1, x2], [y1, y2], color='red')
        plt.title(f"Cluster {i+1} MST")
        plt.xlabel("X")
        plt.ylabel("Y")
        plt.show()
    
    # Connect the clusters using Prim's algorithm
    centers_mst_edges, centers_weight = prims_mst(centers)
    for u, v in centers_mst_edges:
        cluster1 = [points[m] for m in range(n) if labels[m] == centers.index(u)]
        cluster2 = [points[m] for m in range(n) if labels[m] == centers.index(v)]
        min_dist = float("inf")
        min_point1, min_point2 = None, None
        for p1 in cluster1:
            for p2 in cluster2:
                dist = euclidean_distance(p1, p2)
                if dist < min_dist:
                    min_dist = dist
                    min_point1, min_point2 = p1, p2
        mst_edges.append((min_point1, min_point2))
        total_weight += min_dist
    
    # Visualize the final MST
    plt.figure()
    for x, y in points:
        plt.scatter(x, y, color='blue')
    for (x1, y1), (x2, y2) in mst_edges:
        plt.plot([x1, x2], [y1, y2], color='red')
    plt.title("Final MST")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.show()
    
    return mst_edges, total_weight

# Cyclone Blob dataset
np.random.seed(42)
num_points = 1000
x = np.random.uniform(-10, 10, num_points)
y = np.random.uniform(-10, 10, num_points)
r = np.sqrt(x**2 + y**2)
theta = np.arctan2(y, x)
x_cyclone = r * np.cos(theta + r / 5)
y_cyclone = r * np.sin(theta + r / 5)
points = list(zip(x_cyclone, y_cyclone))

# Example usage
fmst_start_time = time.time()
mst_edges, fmst_weight = fast_mst(points)
fmst_end_time = time.time()
fmst_edgecount = len(mst_edges)
fmst_elapsed_time = fmst_end_time - fmst_start_time
print("Time taken by fast MST:", fmst_elapsed_time)
print("Total weight of the MST:", fmst_weight)
# Out:
# Time taken by fast MST: 14.684452295303345
# Total weight of the MST: 433.86145719473416

# %%
import time
from sklearn.cluster import KMeans
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
import numpy as np

def euclidean_distance(p1, p2):
    return sum((a - b) ** 2 for a, b in zip(p1, p2)) ** 0.5

def prims_mst(points):
    n = len(points)
    pairwise_distances = squareform(pdist(points))
    
    mst_edges = []
    total_weight = 0
    visited = [False] * n
    visited[0] = True
    
    for _ in range(n - 1):
        min_weight = float("inf")
        min_u, min_v = None, None
        
        for u in range(n):
            if visited[u]:
                for v in range(n):
                    if not visited[v] and pairwise_distances[u][v] < min_weight:
                        min_weight = pairwise_distances[u][v]
                        min_u, min_v = u, v
        
        mst_edges.append((points[min_u], points[min_v]))
        total_weight += min_weight
        visited[min_v] = True
    
    return mst_edges, total_weight

def fast_mst(points):
    n = len(points)
    k = int(n**0.5)
    
    # Divide-and-conquer stage
    kmeans = KMeans(n_clusters=k).fit(points)
    labels = kmeans.labels_
    centers = kmeans.cluster_centers_.tolist()
    
    mst_edges = []
    total_weight = 0
    
    for i in range(k):
        cluster_points = [points[j] for j in range(n) if labels[j] == i]
        cluster_mst_edges, cluster_weight = prims_mst(cluster_points)
        mst_edges.extend(cluster_mst_edges)
        total_weight += cluster_weight
    
    # Connect the clusters using Prim's algorithm
    centers_mst_edges, centers_weight = prims_mst(centers)
    for u, v in centers_mst_edges:
        cluster1 = [points[m] for m in range(n) if labels[m] == centers.index(u)]
        cluster2 = [points[m] for m in range(n) if labels[m] == centers.index(v)]
        min_dist = float("inf")
        min_point1, min_point2 = None, None
        for p1 in cluster1:
            for p2 in cluster2:
                dist = euclidean_distance(p1, p2)
                if dist < min_dist:
                    min_dist = dist
                    min_point1, min_point2 = p1, p2
        mst_edges.append((min_point1, min_point2))
        total_weight += min_dist
    
    return mst_edges, total_weight

# Cyclone Blob dataset
np.random.seed(42)
num_points = 1000
x = np.random.uniform(-10, 10, num_points)
y = np.random.uniform(-10, 10, num_points)
r = np.sqrt(x**2 + y**2)
theta = np.arctan2(y, x)
x_cyclone = r * np.cos(theta + r / 5)
y_cyclone = r * np.sin(theta + r / 5)
points = list(zip(x_cyclone, y_cyclone))

# Compute MST using FMST algorithm
fmst_start_time = time.time()
fmst_edges, fmst_weight = fast_mst(points)
fmst_end_time = time.time()
fmst_elapsed_time = fmst_end_time - fmst_start_time
print("Time taken by fast MST:", fmst_elapsed_time)
print("Total weight of the MST (FMST):", fmst_weight)

# Compute MST using Prim's algorithm
prims_start_time = time.time()
prims_edges, prims_weight = prims_mst(points)
prims_end_time = time.time()
prims_elapsed_time = prims_end_time - prims_start_time
print("Time taken by Prim's MST:", prims_elapsed_time)
print("Total weight of the MST (Prim's):", prims_weight)
# Out:
# Time taken by fast MST: 0.2038865089416504
# Total weight of the MST (FMST): 433.86145719473416
# Time taken by Prim's MST: 34.28270411491394
# Total weight of the MST (Prim's): 421.5142073583706

# %%
import time
from sklearn.cluster import KMeans
from scipy.spatial.distance import pdist, squareform
from sklearn.datasets import make_blobs
import numpy as np

def euclidean_distance(p1, p2):
    return sum((a - b) ** 2 for a, b in zip(p1, p2)) ** 0.5

def prims_mst(points):
    n = len(points)
    pairwise_distances = squareform(pdist(points))
    
    mst_edges = []
    total_weight = 0
    visited = [False] * n
    visited[0] = True
    
    for _ in range(n - 1):
        min_weight = float("inf")
        min_u, min_v = None, None
        
        for u in range(n):
            if visited[u]:
                for v in range(n):
                    if not visited[v] and pairwise_distances[u][v] < min_weight:
                        min_weight = pairwise_distances[u][v]
                        min_u, min_v = u, v
        
        mst_edges.append((points[min_u], points[min_v]))
        total_weight += min_weight
        visited[min_v] = True
    
    return mst_edges, total_weight

def fast_mst(points):
    n = len(points)
    k = int(n**0.5)
    
    # Divide-and-conquer stage
    kmeans = KMeans(n_clusters=k).fit(points)
    labels = kmeans.labels_
    centers = kmeans.cluster_centers_.tolist()
    
    mst_edges = []
    total_weight = 0
    
    for i in range(k):
        cluster_points = [points[j] for j in range(n) if labels[j] == i]
        cluster_mst_edges, cluster_weight = prims_mst(cluster_points)
        mst_edges.extend(cluster_mst_edges)
        total_weight += cluster_weight
    
    # Connect the clusters using Prim's algorithm
    centers_mst_edges, centers_weight = prims_mst(centers)
    for u, v in centers_mst_edges:
        cluster1 = [points[m] for m in range(n) if labels[m] == centers.index(u)]
        cluster2 = [points[m] for m in range(n) if labels[m] == centers.index(v)]
        min_dist = float("inf")
        min_point1, min_point2 = None, None
        for p1 in cluster1:
            for p2 in cluster2:
                dist = euclidean_distance(p1, p2)
                if dist < min_dist:
                    min_dist = dist
                    min_point1, min_point2 = p1, p2
        mst_edges.append((min_point1, min_point2))
        total_weight += min_dist
    
    return mst_edges, total_weight

# Generate blob dataset using scikit-learn
n_samples = 1000
n_centers = 4
X, _ = make_blobs(n_samples=n_samples, centers=n_centers, random_state=42)
points = X.tolist()

# Compute MST using FMST algorithm
fmst_start_time = time.time()
fmst_edges, fmst_weight = fast_mst(points)
fmst_end_time = time.time()
fmst_elapsed_time = fmst_end_time - fmst_start_time
print("Time taken by fast MST:", fmst_elapsed_time)
print("Total weight of the MST (FMST):", fmst_weight)

# Compute MST using Prim's algorithm
prims_start_time = time.time()
prims_edges, prims_weight = prims_mst(points)
prims_end_time = time.time()
prims_elapsed_time = prims_end_time - prims_start_time
print("Time taken by Prim's MST:", prims_elapsed_time)
print("Total weight of the MST (Prim's):", prims_weight)
# Out:
# Time taken by fast MST: 0.2175743579864502
# Total weight of the MST (FMST): 201.94970026006146
# Time taken by Prim's MST: 35.2403769493103
# Total weight of the MST (Prim's): 196.99578659424827
